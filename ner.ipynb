# %%
import spacy
from spacy import displacy

NER = spacy.load("en_core_web_sm")
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\User\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\User\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\User\AppData\Local\Programs\Python\Python37\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# ### Tweets scraping

# %%
# Python Script to Extract tweets of a
# particular Hashtag using Tweepy and Pandas
 
# import modules
import pandas as pd
import tweepy
 
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
 
 
# function to perform data extraction
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)
 
if __name__ == '__main__':
 
        # Variables that contains the credentials to access Twitter API
        ACCESS_TOKEN = '1472638099490439170-yIq47dBq8EcUuO44msP5CuggeeZBml'
        ACCESS_SECRET = 'swIQSmcUdqZ8XYlzrvnF08IBuzamva5W6b8dUDuXAFxkT'
        CONSUMER_KEY = '5etHstBqMcYpIDESsQPvvhyJO'
        CONSUMER_SECRET = 'cgsmFFYBHPZX7QqeauuwQQgdLgM2RvLnMbvDyJoHYCuOEKo0Gd'


        # Setup access to API
        def connect_to_twitter_OAuth():
            auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
            auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

            api = tweepy.API(auth)
            return api


        # Create API object
        api = connect_to_twitter_OAuth()
 
        # Enter Hashtag and initial date
        print("Enter Twitter HashTag to search for")
        words = input()
        print("Enter Date since The Tweets are required in yyyy-mm--dd")
        date_since = input()
 
        # number of tweets you want to extract in one run
        numtweet = 100
        scrape(words, date_since, numtweet)
        print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# Enter Date since The Tweets are required in yyyy-mm--dd
#
# Tweet 1:
# Username:Ycaiccedov
# Description:maracucha rockera opositora amo los gatos defnsoara dlas mascotas d la calle fe y esperanza puestas en la libertad... dios con nosotros🐕😺
# Location:Carabobo, Venezuela
# Following Count:245
# Follower Count:108
# Total Tweets:7656
# Retweet Count:76
# Tweet Text:🎖️HFH 5th #NFTGiveaway 🎁
#
# 🎁3 winners selected, each wins 1x Hyena #NFT chosen TONIGHT @ 10:00 PM EST⏰
#
# 👇To enter:
# 1⃣RT + Follow @HedgeFundHyenas
# 2⃣Join Discord: https://t.co/Nk6ddqUjWw
#
# While in Discord, come talk NFT/crypto investments with our #NFTCommunity &amp; the HFH team! https://t.co/U8hdAX7qF7
# Hashtags Used:['NFTGiveaway', 'NFT']
#
# Tweet 2:
# Username:Caterrific_
# Description:#NFT #PLAY2EARN #PLAYTOEARN #CRYPTO #GAMING #CRYPTOGAMING #BLOCKCHAIN #BNB #BTC #Bitcoin #ETH #ALTS
# Location:Schweiz
# Following Count:1406
# Follower Count:800
# Total Tweets:22774
# Retweet Count:46
# Tweet Text:$TCT #wildcardgame @wildcardp2e - sounds like best crypto game !! Great Stuff !! There are three ways to ultimate success: The first way is to be kind. The second way is to be kind. The third way is to be kind. Bullish!! #BlueChipTaco #Shiba https://t.co/qgW4t3MsLh
# Hashtags Used:['wildcardgame']
#
# Tweet 3:
# Username:Aleksei86059415
# Description:
# Location:
# Following Count:3
# Follower Count:1
# Total Tweets:3
# Retweet Count:15
# Tweet Text:The NFT Collection from @KittyDinger
# launches this month! 🚀
#
# 80 Unique Traits 🥳
# 3000 Supply 🪙
#
# Join the community today!
# #NFT #crypto #defi https://t.co/VFpuEWqlCW
# Hashtags Used:[]
#
# Tweet 4:
# Username:bbeyondm1
# Description:Luxury Affordable Massage - Beyond Massage -beyond ordinary was Established in 2015 as a client centered care personalized attention Massage Salon
# Location:San Diego, CA
# Following Count:3010
# Follower Count:990
# Total Tweets:5827
# Retweet Count:3
# Tweet Text:@_Lady_Crypto_ Sometimes being crazy #Shiba 🤣 https://t.co/5RgvjL4AMO
# Hashtags Used:['Shiba']
#
# Tweet 5:
# Username:Crypto_And_Kush
# Description:🤜🤛💨💨🚀🚀Crypto and legalized weed enthusiast. Wake, bake and stake
# #cro #Fftb I'm part of the #crofam
#  #LoadedLion #3147 #cronoschimp and #madmeerkat
# Location:Land of the Free
# Following Count:336
# Follower Count:307
# Total Tweets:387
# Retweet Count:0
# Tweet Text:Wish I knew about @EbisusBay VIP pass earlier but got a founding
#  member NFT 🤟
# Use my referral code ZH7Te5fq2z for 5% off the pass which give you discounts on mints going forward. https://t.co/iZRPWypiaU
# Hashtags Used:[]
#
# Tweet 6:
# Username:11091989shevchu
# Description:
# Location:
# Following Count:204
# Follower Count:1
# Total Tweets:155
# Retweet Count:34
# Tweet Text:#InfamArmy❗ Guys, you are the best❗
#
# Our Discord server has just 1 week old🔥🔥🔥 But we hit 1000 users!
#
# Don’t forget to use it and invite friends to get some prizes🏆
#
# #INF #marketing #InfamPlatform #startup #Infam #INFtoken #crypto #DeFi #InfamDiscord https://t.co/NaIWwhghJm
# Hashtags Used:['InfamArmy']
#
# Tweet 7:
# Username:Crypto_D_
# Description:Cryptobabe cruising the metaverse 🔥🚀🍋📈 #magichero #varrior $vpad $mcrt
# Location:
# Following Count:717
# Follower Count:153
# Total Tweets:2104
# Retweet Count:102
# Tweet Text:8000 FOLLOWERS! 🏹
#
# Let’s hit 10K TODAY!
#
# RETWEET, LIKE &amp; SHARE!
# Hashtags Used:[]
#
# Tweet 8:
# Username:88bigw1n_2022
# Description:Bismillah diparingi ikhlas,ridho Allah 🙏
# #jihantesti #BUNALOVE #cutetesty #unclebongtesti #6️⃣5️⃣🎹
#  #kimlovers
# #testinyafina #sobatgarangan #hadiahibuk
# Location:Jawa Tengah, Indonesia
# Following Count:4951
# Follower Count:138
# Total Tweets:25129
# Retweet Count:8156
# Tweet Text:$500 | 7 JUTA RUPIAH OR IPHONE XR FOR ONE WINNER IN 72 HRS 🕊
#
# - retweet &amp; follow (turn on all notif 🔔)
#
# @GAContest_
# @Crypto_Contest_
# @Crypto_Adams https://t.co/JdAFZkiKxt
# Hashtags Used:[]
#
# Tweet 9:
# Username:Crypto__Trends
# Description:PhD student, digging trend lines, market sentiment and #crypto facts. #Follow me for occasional thoughts and I will #followback. Not Financial Advice.
# Location:Boston, MA
# Following Count:74
# Follower Count:27
# Total Tweets:43
# Retweet Count:0
# Tweet Text:@FootBal82842539 @sunflowerfarmz No worries, your "investment" has already been recovered by someone else :). Thanks for playing with us.
# Hashtags Used:[]
#
# Tweet 10:
# Username:andre_ks04
# Description:semoga bisa segera big win 🍀🍀🍀 #LegitFAM #LiT #CBLove 6️⃣5️⃣🎹 #tigergang #funsizedw1n
# Location:Bekasi bisa, Jakarta juga bisa
# Following Count:4935
# Follower Count:273
# Total Tweets:69063
# Retweet Count:724
# Tweet Text:$100 || RT in 12hrs 🐯❤
#
# Follow @j_crypto_2015 + RT their 📌
# Hashtags Used:[]
#
# Tweet 11:
# Username:WomanNFT
# Description:WomanNFT.ETH WomanNFT.Tez. Pop CryptoArtist. Making the world a better place for our children through Art, Love and Community. ❤️ My opinions are my own.
# Location:Home
# Following Count:9038
# Follower Count:15265
# Total Tweets:57178
# Retweet Count:0
# Tweet Text:@Crypto_Breezy7 @cyber_yuyu @CakedApes Cake cake cake cake cake 🎶🎶🎶
# Hashtags Used:[]
#
# Tweet 12:
# Username:maknmyendz
# Description:Crypto enthusiast trying to reach the moon one coin at a time 🪙🚀
# $Kiba
# Location:
# Following Count:659
# Follower Count:387
# Total Tweets:16560
# Retweet Count:0
# Tweet Text:@DoloNFT KIBA IS JUST BREAKING WORLD RECORDS...PROLY NOTHING 🤔
# $KIBA #KIBA #MEMECOIN #CRYPTO #ALTCOIN
#
# https://t.co/6D8UfslftE
#
# Telegram: https://t.co/DGSG3gnlvl
# Twitter: @KibaInuKiba
# Website: https://t.co/W5jKN5PaxT
# https://t.co/iWWYUvu6Z6
# Hashtags Used:['KIBA', 'MEMECOIN', 'CRYPTO', 'ALTCOIN']
#
# Tweet 13:
# Username:elgilban914
# Description:hanya pencari recehan yg di kasih amanah oleh maha pencipta untuk terus berusaha.. karena tiada usaha yang sia sia.
# Location:Bungbulang, Indonesia
# Following Count:3986
# Follower Count:158
# Total Tweets:18729
# Retweet Count:0
# Tweet Text:@Crypto_Contest_ Done https://t.co/rnHNDZg4iP
# Hashtags Used:[]
#
# Tweet 14:
# Username:YashSharma1705
# Description:
# Location:India
# Following Count:711
# Follower Count:601
# Total Tweets:41828
# Retweet Count:50
# Tweet Text:The exercise of an buying bullish on $TCT is the supremist pleasure in life.   -  #TacoCatToken takeover #Crypto
#
# The ultimate in #P2E #WildCardGame from #BlueChipTaco https://t.co/eYn2uPo7Ph
# Hashtags Used:['TacoCatToken', 'Crypto']
#
# Tweet 15:
# Username:Bubble_minakie
# Description:Believer. Singer. Gooner. Messi.Jersey plug. Econs major. Social media manager/consultant. IG:@mz_muna. For ads/promo: 📧 bogunjokoeb@gmail.com.
# Location:Emirates.
# Following Count:22795
# Follower Count:37579
# Total Tweets:158721
# Retweet Count:0
# Tweet Text:My birthday is on the 21st of January and here’s what I want:
# Crypto
# Credit alerts
# Dresses
# Wigs from @_Matriach
# Bags and shoes from @Tbillion40
# AirPods 3 from @DrightSauce
# Series 7 Smartwatch from @sire_frank
# Sea food, ijekuje and you can throw in some pararan.
# Thank you ❤️
# Hashtags Used:[]
#
# Tweet 16:
# Username:Danielesesta81
# Description:#OccupyDeFi✊ #PeopleMaxi - Together we are
# One - Frog Nation - 🐸🐸🤝💪 Do not Live asking
# Permission
# Location:🌖
# Following Count:0
# Follower Count:34
# Total Tweets:39
# Retweet Count:0
# Tweet Text:@ojhalm How is the crypto market going for you? Send A Dm
# Hashtags Used:[]
#
# Tweet 17:
# Username:wycing61
# Description:Hihi
# Location:
# Following Count:89
# Follower Count:8
# Total Tweets:60
# Retweet Count:85
# Tweet Text:$LUFFY looking super bullish! Just waiting for the $LUFFY own NFT market place. Buy #LUFFY on uniswap (not on exchange), so you can get free token as reflections.
#
# $LUFFY #LUFFY #LUFFYCREW #SHIB #FLOKI #SAITAMA #crypto #ETH #dogelon #kishu #Bitcoin #cryptocurrency https://t.co/LpecVD6lKk
# Hashtags Used:['LUFFY']
#
# Tweet 18:
# Username:AndresDSA24
# Description:Redactando...
# Location:
# Following Count:10
# Follower Count:1
# Total Tweets:9
# Retweet Count:1588
# Tweet Text:🎁 #FirstAirdrop2022 🎁
#
# 1000$ giveaway
# Next 10 winners ✨
#
# 1. Follow @kedruga and rt this tweet
# 2. Comment your BSC wallet 👀
#
# #Airdrop #Giveaway #Crypto #cryptocurrency #NFTs #NFTGiveaway #SHIB #BabyCheemsInu https://t.co/G2vZJiU3TX
# Hashtags Used:['FirstAirdrop2022']
#
# Tweet 19:
# Username:BukanGhoib
# Description:Tiada hasil tanpa usaha
# Indonesia Tanah Air Beta
# @DanielRoedy
# #IwonHanabi
# #JihanTesty
# Location:Genting
# Following Count:3687
# Follower Count:109
# Total Tweets:14727
# Retweet Count:8156
# Tweet Text:$500 | 7 JUTA RUPIAH OR IPHONE XR FOR ONE WINNER IN 72 HRS 🕊
#
# - retweet &amp; follow (turn on all notif 🔔)
#
# @GAContest_
# @Crypto_Contest_
# @Crypto_Adams https://t.co/JdAFZkiKxt
# Hashtags Used:[]
#
# Tweet 20:
# Username:Amirasa67481921
# Description:
# Location:
# Following Count:117
# Follower Count:0
# Total Tweets:88
# Retweet Count:96
# Tweet Text:New Airdrop: Pope Inu
# Value: $100,000
# Rewards: 10,000,000 POPE
# Winners: 3000 Winners
# End Date: 9th February, 2022
# Distribution: After PancakeSwap listing
#
# 🔗 Fill the Airdrop Form: https://t.co/ULgyrWS223
#
# #Airdrop #Crypto #Bitcoin #BSC #AirdropAchiever #PopeInu https://t.co/8Sr6sv8PHo
# Hashtags Used:[]
#
# Tweet 21:
# Username:HinuChad1
# Description:(He/Nu)
# Location:
# Following Count:10
# Follower Count:4
# Total Tweets:34
# Retweet Count:0
# Tweet Text:@memetoolsapp $HINU #HeliumInu Developing a #BNB staking Battle Royale video game #NFT collection, #BUSD reflection payments
# Gaming and NFTs are the future of crypto, don't miss out! @HinuDev
# We are listed on CoinMarketCap! We have officially breached $1M mc
# #CMC #HeliumInu $HINU #BSCGemsAlert
# Hashtags Used:['HeliumInu', 'BNB', 'NFT', 'BUSD', 'CMC', 'HeliumInu', 'BSCGemsAlert']
#
# Tweet 22:
# Username:YashSharma1705
# Description:
# Location:India
# Following Count:711
# Follower Count:601
# Total Tweets:41828
# Retweet Count:48
# Tweet Text:Sometimes the most important thing in a whole day is the bullish $TCT we buy.    - #TacoCatToken #Crypto for the mainstream
#
# #WildCardGame #WildcardP2E is the game changing #P2E from #BlueChipTaco https://t.co/eWFzKf3rgC
# Hashtags Used:['TacoCatToken', 'Crypto']
#
# Tweet 23:
# Username:itejck
# Description:I ❤️ Crypto Tokenomics that can help those who need it most. ❤️ #Defi ❤️ 🥷 $SHINJA #SHINJA 🥷#DOJOSWAP #KATANAWALLET #KUSARIBLOCKCHAIN #DOJOVERSE #blockchain
# Location:
# Following Count:853
# Follower Count:486
# Total Tweets:12634
# Retweet Count:0
# Tweet Text:@OC_CryptoNurse @WatcherGuru If you haven’t grabbed #SHINJA yet, it’s a smart time to swoop a bag. 🦾🥷❤️
# 🥷#DOJOSWAP 🥷🌎🚀🌚
# 🥷#KATANAWALLET🥷🥷🌎🚀🌚                             🥷#DOJOVERSE 🥷🥷🥷🌎🚀🌚
# 🥷#KUSARIBLOCKCHAIN 🥷🌎🚀🌚#DeFi #crypto #cryptocurrency #blockchain #NFT #Shibnobi #DeFi @Shib_nobi
# Hashtags Used:['SHINJA', 'DOJOSWAP', 'KATANAWALLET', 'DOJOVERSE', 'KUSARIBLOCKCHAIN', 'DeFi', 'crypto', 'cryptocurrency', 'blockchain', 'NFT', 'Shibnobi', 'DeFi']
#
# Tweet 24:
# Username:CRYPTO_VIIKING
# Description:.
# Location:
# Following Count:218
# Follower Count:66
# Total Tweets:2324
# Retweet Count:5
# Tweet Text:#Listen_audio
# Last tym
# I updated perfectly
#
# Again updating
#
# Positional long only above $46440/$47800 monthly close
#
# 12H/1D close above $44500 may give $46440
#
# @futrii @AltsOracle @EmmaLladro @TARNEETSINGH  @Upndown05402148 @tessa_dawn1
#
# #RETWEET IF U FIND IT WORTH to help others https://t.co/IpiIZyi3kq https://t.co/qTCjEhhdPO
# Hashtags Used:['Listen_audio']
#
# Tweet 25:
# Username:Hooters
# Description:New year. Same owl. Use code NEWYEAR for $10 off $50+ orders on the Hooters app or https://t.co/EsaVH7ISJl
# Location:
# Following Count:2885
# Follower Count:142176
# Total Tweets:74441
# Retweet Count:0
# Tweet Text:Thinking of creating my own crypto and calling it #TitCoin
# Hashtags Used:['TitCoin']
#
# Tweet 26:
# Username:Crypto_Igloo
# Description:🥷        I love crypto.   🥷
# Location:Vancouver, British Columbia
# Following Count:1397
# Follower Count:359
# Total Tweets:1617
# Retweet Count:1
# Tweet Text:What is Bitboy's insider doing anyway, is he still on the board of Ripple?😂 https://t.co/CgZxxcZjP7
# Hashtags Used:[]
#
# Tweet 27:
# Username:wangibigwin2022
# Description:Akun khusus GA (only one my GA Acc)ʕ·ᴥ·ʔ💎🍀 #6️⃣5️⃣🎹 #Gabbies ❤️ #LiT bismillah bisa debut di #jihantesti ❤️
# Location:🇮🇩
# Following Count:4972
# Follower Count:299
# Total Tweets:38415
# Retweet Count:621
# Tweet Text:🚀 NEXT X100 IDO 🚀
#
# PayTrust is a revolutionary platform in the crypto payments space.
#
# They allow REFUNDS FOR THE FIRST TIME IN THE HISTORY OF THE BLOCKCHAIN!
#
# ✅ AUDIT - KYC - TEAM DOXXED. ✅
#
# IDO link: https://t.co/iiYMLMXkHS
# TG Group: https://t.co/KsdLISbhV2 https://t.co/O0ze6QdZ3A
# Hashtags Used:[]
#
# Tweet 28:
# Username:BlogPuerto
# Description:
# Location:
# Following Count:461
# Follower Count:96
# Total Tweets:4918
# Retweet Count:0
# Tweet Text:@WatcherGuru 2022 the Shiba Inu Year! Why? Simple, #Shibarium, the Game, solid and secure ecosystem and the most importantly, the community. Real people that are 100% sure that #Shib will be into the first 5 crypto established projects in the world and a Global Currency for the next century!
# Hashtags Used:['Shibarium', 'Shib']
#
# Tweet 29:
# Username:FinancialNews
# Description:FN is the leading source of information about the investment banking, fund management and securities industries.
# Location:London
# Following Count:360
# Follower Count:61167
# Total Tweets:92671
# Retweet Count:0
# Tweet Text:Crypto broker Bitcoin Suisse snaps up Barclays exec for CEO role https://t.co/zxw1ycMo3a
# Hashtags Used:[]
#
# Tweet 30:
# Username:quote_crypto
# Description:Given cryptocurrency's current price in USD. Price Updates every 5 minutes. DM and I'll add any other crypto
# Location:
# Following Count:1
# Follower Count:21
# Total Tweets:9916
# Retweet Count:0
# Tweet Text:Crypto Prices (USD/₿)
#
# Bitcoin ➨ $41563.6764➷
# AxieInfinity ➨ $72.849➷
# VeChain ➨ $0.0791➷
# EthereumClassic ➨ $23.6092➷
# InternetComputer ➨ $30.8705➷
# EOS ➨ $2.8552➷
#
# #Crypto #Bitcoin #AxieInfinity #VeChain #EthereumClassic #InternetComputer #EOS
# Hashtags Used:['Crypto', 'Bitcoin', 'AxieInfinity', 'VeChain', 'EthereumClassic', 'InternetComputer', 'EOS']
#
# Tweet 31:
# Username:OluwaGbenga98
# Description:Digital/Affiliate Marketer || Videography || Blogger || Shoe Maker
# Location:Lagos, Nigeria
# Following Count:327
# Follower Count:40
# Total Tweets:135
# Retweet Count:119
# Tweet Text:NFT’s can make you rich
# Crypto can make you rich
# YouTube can make you rich
# Real Estate can make you rich
# Social media can make you rich
# E-Commerce can make you rich
# Email marketing can make you rich
#
# All of them work. You just need to choose something &amp; stick with it.
# Hashtags Used:[]
#
# Tweet 32:
# Username:krypticrooks
# Description:CEO of Chad Capital... never made it @shitinvest
# Member // @pleasrDAO
# Location:Dallas, TX
# Following Count:1652
# Follower Count:8304
# Total Tweets:25713
# Retweet Count:0
# Tweet Text:how to avoid problems with sec when building crypto project. Launch roadmap "buy this no cap you gunna be rich fam"... profit... stress free relaxation time
# Hashtags Used:[]
#
# Tweet 33:
# Username:drnitinchaube
# Description:CEO & CMD-HBH - Health Beyond Healing Pvt Ltd (https://t.co/Dd6h0Hehhx), Senior Partner AAUHT-HBH JV, ICELAND, COVID AYURVEDIC SUPPORT & COUNSELLING
# Location:Chennai, Tamil Nadu
# Following Count:403
# Follower Count:554
# Total Tweets:26480
# Retweet Count:0
# Tweet Text:#cryptocrash seems the top trend now
# #Bitcoin #BTC #dogecoin #shiba #Crypto #cryptocurrency #cryptocurrencies
# Hashtags Used:['cryptocrash', 'Bitcoin', 'BTC', 'dogecoin', 'shiba', 'Crypto', 'cryptocurrency', 'cryptocurrencies']
#
# Tweet 34:
# Username:Caterrific_
# Description:#NFT #PLAY2EARN #PLAYTOEARN #CRYPTO #GAMING #CRYPTOGAMING #BLOCKCHAIN #BNB #BTC #Bitcoin #ETH #ALTS
# Location:Schweiz
# Following Count:1406
# Follower Count:800
# Total Tweets:22775
# Retweet Count:42
# Tweet Text:$TCT @wildcardp2e can't wait to play #wildcardgame !! Bullish !! Success is getting what you want, happiness is wanting what you get. Bullish!! #BlueChipTaco #Crypto https://t.co/mK5SAZ9XI9
# Hashtags Used:['wildcardgame']
#
# Tweet 35:
# Username:BobChatter1
# Description:
# Location:
# Following Count:262
# Follower Count:168
# Total Tweets:9534
# Retweet Count:31
# Tweet Text:Am I genuinely missing something? Keep seeing the word dip? You call this a dip?! Zoom out people #safemoon has had one of the strongest couple of weeks in the entire established #crypto world. Most things are tanking. https://t.co/KrXU8Ocr88
# Hashtags Used:['safemoon']
#
# Tweet 36:
# Username:coin_guru
# Description:Follow Us for Real-time #Cryptocurrency Price Alerts, Breaking News and cool #Giveaway Contests. Stay ahead of the markets & Turn on 🔔 Notifications here! 👆
# Location:
# Following Count:280
# Follower Count:17160
# Total Tweets:10053
# Retweet Count:0
# Tweet Text:NEAR Protocol falling! 📉
#
# 1 NEAR is now $15.2190 (Down 3.58% in 1 hour)
#
# Buy, Sell or HODL?
#
# https://t.co/tFf1M9pifu
#
# #NEARProtocol #NEAR $NEAR #crypto
# Hashtags Used:['NEARProtocol', 'NEAR', 'crypto']
#
# Tweet 37:
# Username:bubblebubblys
# Description:just turn off my retweets, mute, or bub me if you feel uncomfortable | cita-cita pake #jihantesti #SobatGarangan #ShillCrew 🤲🏻
# Location:HUNTER, SBT, ARCHIVE ACCOUNT ✨
# Following Count:4883
# Follower Count:129
# Total Tweets:33667
# Retweet Count:328
# Tweet Text:$25 | 350K ~ ends in 3 hours
#
# • RT + Follow @Crypto_GA_Arena
# • Join/Rt their 📌
# Hashtags Used:[]
#
# Tweet 38:
# Username:alyapoomcityx
# Description:30:20:50 Kpopers : random : Thai enthu. yang gak nyaman boleh unfoll ya 😙 otw #jihantesti #cutetesty
# Location:taynew
# Following Count:1022
# Follower Count:144
# Total Tweets:11671
# Retweet Count:0
# Tweet Text:Excellent project! https://t.co/bqIC8aDBap #CryptoRocketLaunch #NFT #Whitelist #NFTGame #PlayToEarn #ToTheMoon
# Hashtags Used:['CryptoRocketLaunch', 'NFT', 'Whitelist', 'NFTGame', 'PlayToEarn', 'ToTheMoon']
#
# Tweet 39:
# Username:MMehrdadmoosavi
# Description:
# Location:
# Following Count:682
# Follower Count:9
# Total Tweets:1263
# Retweet Count:1741
# Tweet Text:Dear community members @pixelverse1 #PIXELROBOT first round is sold out.
# We will open a second round shortly
# Please stay tuned for this fantastic collection🚀🚀🚀🚀
# #crypto #NFT #blockchain #NFTGaming #Metaverse https://t.co/dpjEXPPPcq
# Hashtags Used:['PIXELROBOT']
#
# Tweet 40:
# Username:zlya7d
# Description:kanekicryptr
# Location:
# Following Count:478
# Follower Count:70
# Total Tweets:885
# Retweet Count:4
# Tweet Text:Who’s ready for the @truth reveal tomorrow?
#
# Seek and you shall find.
#
# @ajt @process_grey #NFTCommunity #Illuminati #ETH #Crypto #Bitcoin #Ethereum #opensea https://t.co/7zqsgYna8g
# Hashtags Used:['NFTCommunity', 'Illuminati']
#
# Tweet 41:
# Username:AmgBruce
# Description:Technical Operations Engineer. LaSalle Engineering 👨🏾‍💻 Master’s Graduate. Global Humility LLC
# Location:Philadelphia
# Following Count:1252
# Follower Count:1632
# Total Tweets:95578
# Retweet Count:0
# Tweet Text:Crypto been shit all 2022 praying for a pump
# Hashtags Used:[]
#
# Tweet 42:
# Username:YashSharma1705
# Description:
# Location:India
# Following Count:711
# Follower Count:601
# Total Tweets:41828
# Retweet Count:52
# Tweet Text:Most smiles are started by bullish $TCT sentiment than another smile.    - #TacoCatToken mainstream #Crypto
#
# Q1-2022 sees #BlueChipTaco release #WildCardGame #WildcardP2E https://t.co/T5mMWGWzse
# Hashtags Used:['TacoCatToken', 'Crypto']
#
# Tweet 43:
# Username:diyojenix
# Description:
# Location:
# Following Count:562
# Follower Count:1340
# Total Tweets:4189
# Retweet Count:46
# Tweet Text:🚨 Free #NFTGiveaway 🚨
# Drop your #ETH wallet address 🎁
#
# Only a chance for the first 400 rt’s!!
#
# To Enter:
# 1️⃣ Follow @ZebraPunks
# 2️⃣ Follow @ijs_003
# 3️⃣ ❤️ &amp; RT
#
# #NFT #NFTCommunity #art #NFTGiveaways #nftcollectors #zebrapunks #NFTs #Airdrop #Airdrops #Crypto #Giveaway https://t.co/nzMyWJDiPs
# Hashtags Used:['NFTGiveaway', 'ETH']
#
# Tweet 44:
# Username:andiesst
# Description:📚 Electronic PGT'25 | TI UEU'17 | MTI UMB'22
# 🔧 Distribution Energy Dept. at PT GJTL
# 🛠️ PT SEP Engineering ( General Contr & Trading )
# Location:tangerang,indonesia
# Following Count:1055
# Follower Count:608
# Total Tweets:20693
# Retweet Count:7049
# Tweet Text:Haven’t you attended our last webinar?
#
# You can watch it now and learn about the essentials of #Candao👇
# https://t.co/Fpc06BK985
#
# 📰Stay updated with the crypto world and check out the news:
# StarTerra Pyromaniac: https://t.co/U6sI6aCuBS
# Expo Poland 2022 https://t.co/xLBbsNFh21 https://t.co/kSBhL2FPzz
# Hashtags Used:['Candao']
#
# Tweet 45:
# Username:DAVIDBS28756184
# Description:Top 50 brawl stars
# (2017&2018)
# Top 20 clash royale
# (2016&2017)
#
# CEO of mortis in heist | Random matchmaking connoisseur | 33k 🏆 🇺🇲 | Immature Twitter user
# Location:
# Following Count:120
# Follower Count:14
# Total Tweets:625
# Retweet Count:0
# Tweet Text:@rzm64 I'm with you, I have not been able to understand a thing about crypto nor NFTs
# Hashtags Used:[]
#
# Tweet 46:
# Username:skrone786
# Description:I am a Freelancer
# Location:
# Following Count:499
# Follower Count:12
# Total Tweets:1836
# Retweet Count:192
# Tweet Text:🚀 Airdrop: Angel Soul
# 💰 Value: $50 NFT
# 👥 Referral: HERO NFT
# 📒 Partnership: King Co, JUMEER, BISKO
# 📗 Investors: Initech, HOOLI, ABAL, BPS CO, JUMEER
# 📆 End Date: 10th January, 2022
#
# Talk with the Telegram Bot
# https://t.co/RBFp0tQ49h
#
# #Airdrop #Crypto #Airdrops #GiveAway https://t.co/7wlLKtgGCB
# Hashtags Used:[]
#
# Tweet 47:
# Username:SanketP64258157
# Description:
# Location:
# Following Count:99
# Follower Count:58
# Total Tweets:547
# Retweet Count:238
# Tweet Text:What’s been the most impressive crypto meme coin of 2022 so far? 🤔
#
# • #Dogecoin
# • #SHIB
# • #Saitama
# • #BabyDogeCoin
# • #FLOKI
# • #KISHU
# • #Shinja
# • ________??
# Hashtags Used:['Dogecoin', 'SHIB', 'Saitama', 'BabyDogeCoin']
#
# Tweet 48:
# Username:TokenTribune
# Description:An opinionated news source for everything crypto and NFT related.
# Location:
# Following Count:9
# Follower Count:1
# Total Tweets:4
# Retweet Count:0
# Tweet Text:Gm.
#
# Our team is here to spread crypto and NFT news to the Twitter community!
#
# This year has already been a wild ride and we are excited to share everything that else that 2022 brings.
# Hashtags Used:[]
#
# Tweet 49:
# Username:_gerald
# Description:physical and metaphysical poet. caregiver. practicer of exercise and speech. river artwork by grasshopper geography. if you don’t get it, it might be a bit
# Location:EST 1982
# Following Count:472
# Follower Count:166
# Total Tweets:1055
# Retweet Count:0
# Tweet Text:@jordanbpeterson @Reel2Reil @spectator Imagine tying it to crypto wallets? As dystopian as one could imagine.
# Hashtags Used:[]
#
# Tweet 50:
# Username:NayanHowlader14
# Description:
# Location:
# Following Count:893
# Follower Count:4
# Total Tweets:2456
# Retweet Count:3512
# Tweet Text:🚀 #Airdrop: Metaverse Lab
# 💰 Value: 50 $MVP
# 👥 Referral: 50 $MVP Tokens each
# 📘 IDO: Polkaex Group, EraxNFT, Yaan Launchpad, CoinSwap Space
# 📒 Partnership: CryptoVerse Xplorer
# 📅 End Date: 3rd Feb 2022
#
# Talk with the Telegram Bot
# https://t.co/1QRtKzZ7in
#
# #Airdrops #Crypto https://t.co/lyWYgChBqe
# Hashtags Used:['Airdrop']
#
# Tweet 51:
# Username:jaemhyuncityx
# Description:#jihantesti #chitawinner soon | CLOSED! Joki Tugas Hukum, resume jurnal, video , buku dan jasa tulis | apple music | WA for fast response (klik link in Bio)👇
# Location:BRI•DANA•OVO•Shopeepay
# Following Count:3734
# Follower Count:57
# Total Tweets:24456
# Retweet Count:574
# Tweet Text:💎💎💎
#
# Show me your beautiful New Year NFT  in the comments! 💯
# In 24Hrs
# I'll pick one and retweet it 🚀
#
# #NFTCommunity #OpenSeaNFT #NFTGaming #NFTGame #NFTshill #NFT #nftcollectors #cryptonft #crypto #shillme #nftart #NFTartists #NFTdrop #NFTs #BTC #BSC
# #Solana
# Hashtags Used:['NFTCommunity']
#
# Tweet 52:
# Username:RealMoonBound
# Description:Pre-Sale and Token Launch coming soon 🚀💰Merchandise, NFT’s, Utility 👀
# Location:Metaverse
# Following Count:95
# Follower Count:472
# Total Tweets:178
# Retweet Count:0
# Tweet Text:@AltcoinDailyio Great note to read. 🗒️
# #wagmi #crypto #future
# Hashtags Used:['wagmi', 'crypto', 'future']
#
# Tweet 53:
# Username:Benzeah
# Description:
# Location:Kota Malang, Jawa Timur
# Following Count:89
# Follower Count:4
# Total Tweets:165
# Retweet Count:6008
# Tweet Text:🚀 Airdrop: BasketballDAO
# 💰 Value: 7200 $BBDAO
# 👥 Referral: 550 $BBDAO
# 📼 Audit: ContractChecker
# 🗞 News: Newsbsc
# 📅 End Date: 11 January 2022
# 🏦 Distribution Date: 12 January 2022
#
# Talk with the Telegram Bot
# https://t.co/N2bQCFoWPC
#
# #Airdrop #Crypto #Airdrops #giveaway https://t.co/0FVmcohBXf
# Hashtags Used:[]
#
# Tweet 54:
# Username:bentoe_86
# Description:
# Location:Pemalang, Indonesia
# Following Count:161
# Follower Count:42
# Total Tweets:214
# Retweet Count:245
# Tweet Text:Crypto gaming will be absolutely HUGE!
# Hashtags Used:[]
#
# Tweet 55:
# Username:NandisCouch
# Description:Don’t ever give up. Tomorrow, you will start your new journey, or you will continue the move forward. Those are your choices. #UnapologeticallyBlack 👊🏾💅🏾
# Location:
# Following Count:1541
# Follower Count:484
# Total Tweets:21037
# Retweet Count:0
# Tweet Text:@Needle_of_Arya I’m sure they overlap with the section of youth that want us to pay off all their student loans because they were “tricked” into borrowing for a worthless degree… all while they “invest” into crypto “currencies” based on nothing.
# Hashtags Used:[]
#
# Tweet 56:
# Username:maknmyendz
# Description:Crypto enthusiast trying to reach the moon one coin at a time 🪙🚀
# $Kiba
# Location:
# Following Count:659
# Follower Count:387
# Total Tweets:16560
# Retweet Count:0
# Tweet Text:@joshnomics Check out our amazing community, and see what you've been missing
# $KIBA #KIBA #MEMECOIN #CRYPTO #ALTCOIN
#
# Telegram: https://t.co/DGSG3gnlvl
# Twitter: @KibaInuKiba
# Website: https://t.co/W5jKN5PaxT
# https://t.co/iWWYUvu6Z6 https://t.co/MLSdnvusVs
# Hashtags Used:['KIBA', 'MEMECOIN', 'CRYPTO', 'ALTCOIN']
#
# Tweet 57:
# Username:grase563
# Description:#CRO #ALH
# #CryptoPres ¯\_(ツ)_/¯   $OPUL
# Location:
# Following Count:976
# Follower Count:168
# Total Tweets:2583
# Retweet Count:7439
# Tweet Text:🎁 #LastAirdrop 🎁
#
# 1000$ giveaway, 10 winners, 100 hours ✨
#
# 1. Follow us and rt this tweet
# 2. Comment your BSC wallets 🤑
#
# 🕺💰😍 Last one before Private Sale 😍💰🕺
#
# #Airdrop #Giveaway #Crypto
# Hashtags Used:['LastAirdrop']
#
# Tweet 58:
# Username:BogoRazvan
# Description:
# Location:
# Following Count:13
# Follower Count:2
# Total Tweets:20
# Retweet Count:2
# Tweet Text:I know I just made this twitter to warn #cryptotwitter about their #fakegurus failing “only up” #Crypto strat around $52k (last week of December 2021) &amp; to watch all these so called experts crumble bc they do no TA or do shit TA, but can I stay at 420 followers for the memes?
# Hashtags Used:['cryptotwitter', 'fakegurus', 'Crypto']
#
# Tweet 59:
# Username:skrone786
# Description:I am a Freelancer
# Location:
# Following Count:499
# Follower Count:12
# Total Tweets:1836
# Retweet Count:0
# Tweet Text:@CryptoTownEU Fantastic project with great potential. The team's dedication and ingenuity with excellent fan support will make this the envy of the crypto world. Glad to be part.
#
# @Imransk02
# @cryptoonline420
# @MegIslam4
# Hashtags Used:[]
#
# Tweet 60:
# Username:LLMC63470779
# Description:
# Location:
# Following Count:148
# Follower Count:2
# Total Tweets:2
# Retweet Count:464
# Tweet Text:First 4000 people to RT get a little @InvsbleFriends / @StonerApeClub
# or @LeopardDynasty
#
# Must be following @Rugal_Bull &amp; @NFTMINES  so I can DM you👍 Crypto 🤗
#
# Chosing  few Lucky winners❤️
# LFG.
#
# Turn on Notification 🔔🔔
# Hashtags Used:[]
#
# Tweet 61:
# Username:genereca
# Description:not loading 9gb/10gb as of today
# Location:
# Following Count:44
# Follower Count:106
# Total Tweets:7978
# Retweet Count:848
# Tweet Text:To celebrate our 500th member joining our 2022 #crypto fund we are giving away a $365 investment to one lucky person. Simply follow us, RT,like and comment on this tweet to be in with a chance of winning. #btc #eth #scarabcapital #win #competition https://t.co/b9i9gqEHmH
# Hashtags Used:['crypto']
#
# Tweet 62:
# Username:NasirAhmedNoel1
# Description:𝘼𝙞𝙧𝙙𝙧𝙤𝙥 𝙆𝙞𝙣𝙜 𝙉𝙚𝙬𝙨 👑 ꪖᦔꪑỉ᭢
#
# Smart China Address : 0x334645C67d2729bdAc80866Ea40F924b6a21d73D
#
# TRC20 Address :
# TSgq1eGsVpbhBiJXBkhrT53hWo8uC8Pk8E
# Location:
# Following Count:1594
# Follower Count:35
# Total Tweets:1889
# Retweet Count:0
# Tweet Text:@Novaland_io This is a Fantastic project with great potential.The team's dedication and ingenuity with excellent fan support will make this the envy of the crypto world. I am so glad to be part of this.
#
# @Fandisoraja
#
# @siimonn_91
#
# @BlogNajmul
#
# @GAHOfficial_TW
#
# @masud888
# Hashtags Used:[]
#
# Tweet 63:
# Username:chaee_Bigwin2
# Description:#6️⃣5️⃣🎹 #TeamPulte #SUPERFAMILY #callistars #kyliegives #ayuminati #VJFAM #Deukiess #NiceHwan #miones #ajummacares #WonByRich #ChauncyGang #NFT
# Location:
# Following Count:1505
# Follower Count:15
# Total Tweets:6041
# Retweet Count:1132
# Tweet Text:💰 Giveaway 💰
#
# WORTH 400 busd | $400 🐸
#
# 🎁 4 lucky winners will get $100 🔥
#
# To Enter:
#
# 1️⃣Follow :
# @Diffuse64745943
# @LaunchNFTs
# @PepeStuff
# @CRYPTO__BUNNIES
# 2️⃣❤️&amp; RT
# 3️⃣📌Tag Friends
#
# ⏰Ends in 24h 💯
#
# #NFTCommunity #Solana https://t.co/OAA6UZluES
# Hashtags Used:[]
#
# Tweet 64:
# Username:jdsNFT
# Description:(3,3) #SolanaNFT Founder, Producer, 3D Artist, Defi Enthusiast. Building in the NFT space: @soundsol_ & @arch_meta.
# Location:Berlin
# Following Count:731
# Follower Count:271
# Total Tweets:299
# Retweet Count:18
# Tweet Text:You guys asked, we delivered. Today is one of those days we pushed hard for you 🤝
#
# Wrapped Staked FHM is here now to increase #utility of our network for community/holders 🧙‍♂️
#
# You make this worth all of the hard work thank you for everything $FHM FAMILY🙌
# #DeFi $FTM #BTC #crypto https://t.co/K97w8EsEQM
# Hashtags Used:[]
#
# Tweet 65:
# Username:Underdog1775
# Description:Trying to make sense of it all.
# Location:
# Following Count:55
# Follower Count:53
# Total Tweets:113
# Retweet Count:0
# Tweet Text:@oxywashere @SohoKidsNFT @BrightPalz Also, excited for some beautiful art from @cardanoproxies minting Jan 8th 7pm UTC. Their project is meaningful and will impact many aspects of crypto and philanthropy. Their art is amazingly detailed and gorgeous. https://t.co/pfrQ0aYMiz
# Hashtags Used:[]
#
# Tweet 66:
# Username:ruto231
# Description:
# Location:
# Following Count:851
# Follower Count:36
# Total Tweets:1639
# Retweet Count:0
# Tweet Text:@potsdao What an amazing project and I know it's going to be a long massive success in the crypto world..
#
# @Slimhil
# @bundostika
# @Zemira25320701
#
# #PotsDao #Solana #SolanaAirdrop #Giveaway
# Hashtags Used:['PotsDao', 'Solana', 'SolanaAirdrop', 'Giveaway']
#
# Tweet 67:
# Username:CryptoTharen
# Description:
# Location:New Jersey, USA
# Following Count:1357
# Follower Count:369
# Total Tweets:1122
# Retweet Count:0
# Tweet Text:" #GreatburninMyteamFinance #GreatburninMyteamCoin aims to bring together the crypto world and athletes
# "
# 🔍
# 🔍
# 🔍
#
# @myteamchain @myteam_finance #BSC
#
# DECENTRALIZATION
# Hashtags Used:['GreatburninMyteamFinance', 'GreatburninMyteamCoin', 'BSC']
#
# Tweet 68:
# Username:noin55685119
# Description:noin
# Location:
# Following Count:2133
# Follower Count:66
# Total Tweets:11954
# Retweet Count:1
# Tweet Text:Good project must be join
# @dggonzalez
# @RT
# @aalamin999
#
# #Airdrop #Crypto #Airdrops #Giveaway https://t.co/V4IUWLvZiK
# Hashtags Used:['Airdrop', 'Crypto', 'Airdrops', 'Giveaway']
#
# Tweet 69:
# Username:crypto_idea_coi
# Description:Way to the Cryptoworld
# Announcement chat: https://t.co/lpOJm9hNjH
# Community chat: https://t.co/RUGBf0FUqE
# Location:
# Following Count:72511
# Follower Count:77384
# Total Tweets:1242
# Retweet Count:0
# Tweet Text:@bitcoin_queen_ @FantomMaker Probably the best January event
# Hashtags Used:[]
#
# Tweet 70:
# Username:shesoleilcityx
# Description:please follow back! @soleilcityx_22 got suspended.
# This is not a multi account.
# Location:
# Following Count:1128
# Follower Count:52
# Total Tweets:3912
# Retweet Count:8156
# Tweet Text:$500 | 7 JUTA RUPIAH OR IPHONE XR FOR ONE WINNER IN 72 HRS 🕊
#
# - retweet &amp; follow (turn on all notif 🔔)
#
# @GAContest_
# @Crypto_Contest_
# @Crypto_Adams https://t.co/JdAFZkiKxt
# Hashtags Used:[]
#
# Tweet 71:
# Username:AHMADYU68893288
# Description:Rada2 Gaptek
# Location:
# Following Count:578
# Follower Count:81
# Total Tweets:1904
# Retweet Count:1
# Tweet Text:@StarlyFinance join first airdrop share their
# @SOHIDRA
# @sudu
# @faintedsad
# @jankoum
# @FaridRached
# @sona
# @fonni
# @tushar
# @riad
# @fauchat
# @vider
# @vidi
# #bsc #crypto
# #bscarmy
# #Earncrypto
# Hashtags Used:[]
#
# Tweet 72:
# Username:AjayPlayx
# Description:
# Location:
# Following Count:598
# Follower Count:42
# Total Tweets:960
# Retweet Count:533
# Tweet Text:🌎MAGIC EDEN x @TheCavemenClub GIVEAWAY🦣
#
# To celebrate Cavemen's listing on ME and their rebranding to #CAVEWORLD, we're giving away 2 Crypto Cavemen NFTs (Worth $500+ EACH)!
#
# Rules:
# 1⃣ Follow @MagicEden_NFT &amp; @TheCavemenClub
# 2⃣ Like &amp; RT
# 3⃣ Tag 3 Friends
#
# WINNER IN 24 HOURS!⌛️ https://t.co/OZ0LDfElMB
# Hashtags Used:['CAVEWORLD']
#
# Tweet 73:
# Username:Deividdjoon
# Description:
# Location:
# Following Count:353
# Follower Count:8
# Total Tweets:2142
# Retweet Count:132
# Tweet Text:New Airdrop: Multiverse (MUER)
# Rewards: 10 MUER (~300$)
# Referral: 10 MUER (~300$)
# Winners: All Participants
# End Date: 25th January, 2022
# Distribution: 25th January, 2022
#
# 🔗 Airdrop Contest: https://t.co/QPM719yyRX
#
# #Airdrop #Crypto #Bitcoin #BSC #AirdropAchiever #Multiverse https://t.co/8tI0ytMy7Z
# Hashtags Used:[]
#
# Tweet 74:
# Username:feftian1
# Description:deposito
# Location:Bandung, Jawa Barat
# Following Count:1887
# Follower Count:42
# Total Tweets:6063
# Retweet Count:1236
# Tweet Text:Yo CKC!
#  What is your favourite #crypto project?
# Hashtags Used:['crypto']
#
# Tweet 75:
# Username:crypto_kfx
# Description:Got bored and found myself on #Opensea.                                       #BAYC 4522. Might share some other boring stuff (like #ApeSec, coming soon…)
# Location:#VegasApes
# Following Count:1204
# Follower Count:1261
# Total Tweets:1286
# Retweet Count:0
# Tweet Text:Had no idea I was gonna end up there last night, but glad I did. Great times with an awesome group! Looking forward to the next time we run into each other #CES2022 #NFTCES #VegasApes #WAGMI https://t.co/9MFFAciLeb
# Hashtags Used:['CES2022', 'NFTCES', 'VegasApes', 'WAGMI']
#
# Tweet 76:
# Username:JAZEBE999
# Description:‏قهرمان خودت باش
# Location:
# Following Count:1003
# Follower Count:5
# Total Tweets:1521
# Retweet Count:6008
# Tweet Text:🚀 Airdrop: BasketballDAO
# 💰 Value: 7200 $BBDAO
# 👥 Referral: 550 $BBDAO
# 📼 Audit: ContractChecker
# 🗞 News: Newsbsc
# 📅 End Date: 11 January 2022
# 🏦 Distribution Date: 12 January 2022
#
# Talk with the Telegram Bot
# https://t.co/N2bQCFoWPC
#
# #Airdrop #Crypto #Airdrops #giveaway https://t.co/0FVmcohBXf
# Hashtags Used:[]
#
# Tweet 77:
# Username:thabiso_kwena
# Description:let me help you promote your crypto project for a small fee 😉
# Location:
# Following Count:1929
# Follower Count:56
# Total Tweets:3428
# Retweet Count:80
# Tweet Text:🎁 #FirstAirdrop2022 🎁
#
# 1000$ giveaway
# Next 10 winners ✨
#
# 1. Follow @kedruga and rt this tweet
# 2. Comment your BSC wallet 👀
#
# #Airdrop #Giveaway #Crypto #cryptocurrency #NFTs #NFTGiveaway #SHIB #BabyCheemsInu https://t.co/Y5JARPwsP7
# Hashtags Used:['FirstAirdrop2022']
#
# Tweet 78:
# Username:KivancSahinbas
# Description:
# Location:
# Following Count:2
# Follower Count:148
# Total Tweets:83
# Retweet Count:0
# Tweet Text:Disappointed with your investment in crypto? Get into day trading and buy reliable stocks without breaking the bank and enjoy returns.
# Hashtags Used:[]
#
# Tweet 79:
# Username:Deividdjoon
# Description:
# Location:
# Following Count:353
# Follower Count:8
# Total Tweets:2142
# Retweet Count:96
# Tweet Text:New Airdrop: Pope Inu
# Value: $100,000
# Rewards: 10,000,000 POPE
# Winners: 3000 Winners
# End Date: 9th February, 2022
# Distribution: After PancakeSwap listing
#
# 🔗 Fill the Airdrop Form: https://t.co/ULgyrWS223
#
# #Airdrop #Crypto #Bitcoin #BSC #AirdropAchiever #PopeInu https://t.co/8Sr6sv8PHo
# Hashtags Used:[]
#
# Tweet 80:
# Username:Caterrific_
# Description:#NFT #PLAY2EARN #PLAYTOEARN #CRYPTO #GAMING #CRYPTOGAMING #BLOCKCHAIN #BNB #BTC #Bitcoin #ETH #ALTS
# Location:Schweiz
# Following Count:1406
# Follower Count:800
# Total Tweets:22775
# Retweet Count:36
# Tweet Text:$TCT #wildcardgame @wildcardp2e - sounds like best crypto game !! Great Stuff !! If you are working on something that you really care about, you don’t have to be pushed. The vision pulls you. Bullish!! #BlueChipTaco #bitcoin https://t.co/hZg6zwEZdT
# Hashtags Used:['wildcardgame']
#
# Tweet 81:
# Username:mkhelfman
# Description:Top #bitcoin writer Medium, Hacker Noon, @cryptowriter_ | newsletter https://t.co/bylLelw0Wv | Books: Consensusland; Bitcoin or Bust; From Bust to Boom
# Location:Maryland, USA
# Following Count:185
# Follower Count:1971
# Total Tweets:4250
# Retweet Count:0
# Tweet Text:@KevinSvenson_ @crypto_birb Market didn’t deliver on expectations, lots of people let down.
# Hashtags Used:[]
#
# Tweet 82:
# Username:itejck
# Description:I ❤️ Crypto Tokenomics that can help those who need it most. ❤️ #Defi ❤️ 🥷 $SHINJA #SHINJA 🥷#DOJOSWAP #KATANAWALLET #KUSARIBLOCKCHAIN #DOJOVERSE #blockchain
# Location:
# Following Count:853
# Follower Count:486
# Total Tweets:12635
# Retweet Count:0
# Tweet Text:@sofianzahrieh7 @WatcherGuru @Shib_nobi If you haven’t grabbed #SHINJA yet, it’s a smart time to swoop a bag. 🦾🥷❤️
# 🥷#DOJOSWAP 🥷🌎🚀🌚
# 🥷#KATANAWALLET🥷🥷🌎🚀🌚                             🥷#DOJOVERSE 🥷🥷🥷🌎🚀🌚
# 🥷#KUSARIBLOCKCHAIN 🥷🌎🚀🌚#DeFi #crypto #cryptocurrency #blockchain #NFT #Shibnobi #DeFi @Shib_nobi
# Hashtags Used:['SHINJA', 'DOJOSWAP', 'KATANAWALLET', 'DOJOVERSE', 'KUSARIBLOCKCHAIN', 'DeFi', 'crypto', 'cryptocurrency', 'blockchain', 'NFT', 'Shibnobi', 'DeFi']
#
# Tweet 83:
# Username:halyesya
# Description:Menjemput sejumput berkat hidup dan kehidupan
# Location:bekasi
# Following Count:1465
# Follower Count:435
# Total Tweets:6921
# Retweet Count:89
# Tweet Text:This week @Binance:
#
# 🔸 Weekly market summary
# 🔸 New NFT sale model
# 🔸 2021 crypto recap
# 🔸 &amp; much more 👇
#
# https://t.co/EhtW2kcFDh
# Hashtags Used:[]
#
# Tweet 84:
# Username:moeosman7
# Description:“Love the life you live. Live the life you love.” ~ Bob Marley. Use my referral link https://t.co/jAkdBbzWi8 to sign up for https://t.co/Y4fjGK43F8 and we both get $25 USD
# Location:Canada
# Following Count:31984
# Follower Count:29091
# Total Tweets:89781
# Retweet Count:1357
# Tweet Text:How to buy Aquagoat? We got you covered! #AquaGoatV2 #aquagoatarmy #BSCGem #PancakeSwap #Crypto https://t.co/SaYGtvJJFJ
# Hashtags Used:['AquaGoatV2', 'aquagoatarmy', 'BSCGem', 'PancakeSwap', 'Crypto']
#
# Tweet 85:
# Username:boicifer
# Description:you gotta be kidding me.
# Location:real nigga headquarters v2
# Following Count:48
# Follower Count:14
# Total Tweets:117
# Retweet Count:0
# Tweet Text:crypto scammers who only target NFT users should be rewarded for their heroic efforts
# Hashtags Used:[]
#
# Tweet 86:
# Username:_SAUCEDALE
# Description:PHOTOGRAPHER|IG:SAUCEDALE saucedalebooking@gmail.com
# Location:Scottsdale, AZ
# Following Count:601
# Follower Count:597
# Total Tweets:17175
# Retweet Count:2
# Tweet Text:@JakeGagain $EGT #ELONGOAT #CLAIMYOURGOAT #EGTARMY #ELONGOATTOKEN #EGT
# If you're not in right now, what's wrong with you??
# IT'S GOING TO KILL SOME(PLURAL) ZEROES!!!!!
# https://t.co/aNQbmoVXgZ
# Hashtags Used:['ELONGOAT', 'CLAIMYOURGOAT', 'EGTARMY', 'ELONGOATTOKEN', 'EGT']
#
# Tweet 87:
# Username:RAMSEYUNKNOWN
# Description:JUST ASK IF YOU  WANT TO KNOW JUST FOUND OUT 8-12-13 MY SON HAS AUTISM NERVOUS BUT LEARNING CANT FAIL MY SON #TEAMFOLLOWBACK #COWBOYSFANFOREVER !!!!!!
# Location:Kansas City, MO
# Following Count:5645
# Follower Count:5156
# Total Tweets:115195
# Retweet Count:0
# Tweet Text:Customers of a crypto exchange in Hong Kong reportedly say their funds are frozen https://t.co/iNjigPtN1m
# Hashtags Used:[]
#
# Tweet 88:
# Username:Danielesesta81
# Description:#OccupyDeFi✊ #PeopleMaxi - Together we are
# One - Frog Nation - 🐸🐸🤝💪 Do not Live asking
# Permission
# Location:🌖
# Following Count:0
# Follower Count:34
# Total Tweets:39
# Retweet Count:0
# Tweet Text:@SIR_VENOM_IK How is the crypto market going for you? Send A Dm
# Hashtags Used:[]
#
# Tweet 89:
# Username:Shantanu31dec
# Description:Jolly nature
# Location:
# Following Count:54
# Follower Count:73
# Total Tweets:3690
# Retweet Count:169
# Tweet Text:I smell #BabyDogeCoin on @binance
#
# RT &amp; FOLLOW us if you BELIEVE
#
# #BabyDoge #BabyDogeCoin· #BabyDogeFamily #Binance #Babydoge1MillionHolder #Crypto
# Hashtags Used:['BabyDogeCoin', 'BabyDoge', 'BabyDogeCoin·', 'BabyDogeFamily', 'Binance']
#
# Tweet 90:
# Username:MattarJamil
# Description:
# Location:Fremont, CA
# Following Count:168
# Follower Count:47
# Total Tweets:752
# Retweet Count:1
# Tweet Text:@CryptoLife4Eva Antis Inu $ANTIS
#
# The hottest meme with tangible, mining utility 🚀
#
# #AntisInu
# #BNB
# #Dogecoinarmy
# @elonmusk
# @cz_binance @MattWallace888 #cryptocurrency #Crypto #NFT #INFINITYTOKEN $IT @DuncanGray #Saitama @SnoopDogg @InuAntis https://t.co/Wf5ydLhIqx
# Hashtags Used:['AntisInu', 'BNB']
#
# Tweet 91:
# Username:mostcurious2
# Description:💖Helping People Earn Passive Income🤑 #CryptoCurrency 🦇🔊#BTC #ETH #TRON #Solana #Gala #Helium 💜🌿#CryptoHippyLady
# Location:Illinois, USA
# Following Count:1937
# Follower Count:1402
# Total Tweets:5796
# Retweet Count:0
# Tweet Text:These are the 5 best performing cryptocurrencies over the past week amid bitcoin bear market #CryptoCurrencies #bitcoin via https://t.co/40V4NhnsH9 https://t.co/0GuT0vdxKp
# Hashtags Used:['CryptoCurrencies', 'bitcoin']
#
# Tweet 92:
# Username:WayneDickison
# Description:Bio is classified Top Secret.
# Location:Both everywhere and nowhere.
# Following Count:672
# Follower Count:674
# Total Tweets:35179
# Retweet Count:0
# Tweet Text:“Crypto mining” https://t.co/qMJJFcJH2b
# Hashtags Used:[]
#
# Tweet 93:
# Username:Habdu88
# Description:Great things
# Location:
# Following Count:151
# Follower Count:44
# Total Tweets:632
# Retweet Count:3
# Tweet Text:What's your favorite down-day strategy for crypto?
# Hashtags Used:[]
#
# Tweet 94:
# Username:0xSivareddy
# Description:Student
# Location:Bargarh, India
# Following Count:2279
# Follower Count:354
# Total Tweets:1941
# Retweet Count:0
# Tweet Text:@SafinSiddiquee @SonuGup49628987 @Crypto_Jargon nice
# Hashtags Used:[]
#
# Tweet 95:
# Username:Millionaire54
# Description:
# Location:
# Following Count:4160
# Follower Count:1165
# Total Tweets:32622
# Retweet Count:174
# Tweet Text:AMC on track to accept Dogecoin, Shiba Inu $SHIB crypto payments in 2022
#
# Source:
# https://t.co/jfTo1vkwIG
# Hashtags Used:[]
#
# Tweet 96:
# Username:quickUP0
# Description:to be better
# Location:
# Following Count:236
# Follower Count:65
# Total Tweets:296
# Retweet Count:0
# Tweet Text:@98Kdao @wikitoptop @CardanoStiftung Project with great potential.The team's dedication and ingenuity with excellent fan support will make this the envy of the crypto world. I am so glad to be part of this.
# @wksm10
# @JayHao8
# @disteleeer
# Hashtags Used:[]
#
# Tweet 97:
# Username:NO_LOOSE_ENDS
# Description:Investor
# Crypto enthusiasts
# NFT collector
# Not a financial advisor
# Location:Texas, USA
# Following Count:65
# Follower Count:15
# Total Tweets:378
# Retweet Count:0
# Tweet Text:Wondering if you should get into #bitcoin?  Maybe #Ethereum? Brace yourself bc this is what it's like to ride the #crypto train https://t.co/3GpIfTRWba
# Hashtags Used:['bitcoin', 'Ethereum', 'crypto']
#
# Tweet 98:
# Username:BlogPuerto
# Description:
# Location:
# Following Count:461
# Follower Count:96
# Total Tweets:4918
# Retweet Count:0
# Tweet Text:@CoinMarketCap 2022 the Shiba Inu Year! Why? Simple, #Shibarium, the Game, solid and secure ecosystem and the most importantly, the community. Real people that are 100% sure that #Shib will be into the first 5 crypto established projects in the world and a Global Currency for the next century!
# Hashtags Used:['Shibarium', 'Shib']
#
# Tweet 99:
# Username:TheRaccoonZzz
# Description:Life is a video game without save button.
# Location:
# Following Count:168
# Follower Count:56
# Total Tweets:76
# Retweet Count:0
# Tweet Text:One thing unbelievable for me is 90% people in crypto and NFT don't know how to read basic charts😐
#
# My frens, this game control by those guys (or raccoon) look at the chart 24/7/365, they have bills or trills to play with. Not these influencers on social. Start learning NOW !
# Hashtags Used:[]
#
# Tweet 100:
# Username:Prince_omobee
# Description:Broke #NFT lover☹️
#
# | Crypto enthusiast | ambassador | @Exeedme #XEDSoldier | @shuttle_one | @MatrixETF
# Location:in my mind😌
# Following Count:1208
# Follower Count:1389
# Total Tweets:28444
# Retweet Count:0
# Tweet Text:📢📢 New Liquidity Pool for @Exeedme $XED
#
# You can now swap $XED directly for $WETH on UniSwap and Polygon Network 🔥🔥
#
# The $XED / $WETH pair is now Live!! Go trade: https://t.co/i4VXb421aL
#
# For more info ⤵️
# https://t.co/LIl4Jmcwq2
#
# #XEDSoldier #DeFi #Crypto #BSC #ETH #NFT https://t.co/9gsoYjm1jb
# Hashtags Used:['XEDSoldier', 'DeFi', 'Crypto', 'BSC', 'ETH', 'NFT']
# Scraping has completed!

# %% [markdown]
# ### Reading scraped tweets csv

# %%
tweets = pd.read_csv(r"C:\Users\User\Documents\C2001\FIT3161_3162\FIT3161\scraped_tweets.csv") 
# df_eth.columns = df_eth.iloc[0]
# df_eth.drop(df_eth.index[[0, 1]], inplace=True)
tweets.head()
# Out:
#    Unnamed: 0         username  \
# 0           0       Ycaiccedov
# 1           1      Caterrific_
# 2           2  Aleksei86059415
# 3           3        bbeyondm1
# 4           4  Crypto_And_Kush
#
#                                          description             location  \
# 0  maracucha rockera opositora amo los gatos defn...  Carabobo, Venezuela
# 1  #NFT #PLAY2EARN #PLAYTOEARN #CRYPTO #GAMING #C...              Schweiz
# 2                                                NaN                  NaN
# 3  Luxury Affordable Massage - Beyond Massage -be...        San Diego, CA
# 4  🤜🤛💨💨🚀🚀Crypto and legalized weed enthusiast. Wa...     Land of the Free
#
#    following  followers  totaltweets  retweetcount  \
# 0        245        108         7656            76
# 1       1406        800        22774            46
# 2          3          1            3            15
# 3       3010        990         5827             3
# 4        336        307          387             0
#
#                                                 text                hashtags
# 0  🎖️HFH 5th #NFTGiveaway 🎁\n\n🎁3 winners selecte...  ['NFTGiveaway', 'NFT']
# 1  $TCT #wildcardgame @wildcardp2e - sounds like ...        ['wildcardgame']
# 2  The NFT Collection from @KittyDinger \nlaunche...                      []
# 3  @_Lady_Crypto_ Sometimes being crazy #Shiba 🤣 ...               ['Shiba']
# 4  Wish I knew about @EbisusBay VIP pass earlier ...                      []

# %% [markdown]
# ### NER

# %%
raw_text=tweets['text'][0]

# %%
print(raw_text)
# Out:
# 🎖️HFH 5th #NFTGiveaway 🎁
#
# 🎁3 winners selected, each wins 1x Hyena #NFT chosen TONIGHT @ 10:00 PM EST⏰
#
# 👇To enter:
# 1⃣RT + Follow @HedgeFundHyenas
# 2⃣Join Discord: https://t.co/Nk6ddqUjWw
#
# While in Discord, come talk NFT/crypto investments with our #NFTCommunity &amp; the HFH team! https://t.co/U8hdAX7qF7

# %%
text1= NER(raw_text)
for word in text1.ents:
    print(word.text,word.label_)
# Out:
# NFTGiveaway ORG
# 3 CARDINAL
# 1x CARDINAL
# NFT ORG
# 10:00 PM EST TIME
# Discord GPE
# NFT ORG
# #NFTCommunity & MONEY
# HFH ORG

# %%
displacy.render(text1,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">🎖️HFH 5th #
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFTGiveaway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  🎁</br></br>🎁
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  winners selected, each wins
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1x
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Hyena #
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chosen TONIGHT @
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10:00 PM EST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ⏰</br></br>👇To enter:</br>1⃣RT + Follow @HedgeFundHyenas</br>2⃣Join Discord: https://t.co/Nk6ddqUjWw</br></br>While in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Discord
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , come talk
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /crypto investments with our
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     #NFTCommunity &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# amp; the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HFH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team! https://t.co/U8hdAX7qF7</div></span>

# %%
doc = NER(raw_text)

for token in doc:
    print((token.text, token.pos_))
# Out:
# ('🎖', 'PROPN')
# ('️HFH', 'NOUN')
# ('5th', 'ADJ')
# ('#', 'SYM')
# ('NFTGiveaway', 'PROPN')
# ('🎁', 'NUM')
# ('\n\n', 'SPACE')
# ('🎁', 'NUM')
# ('3', 'NUM')
# ('winners', 'NOUN')
# ('selected', 'VERB')
# (',', 'PUNCT')
# ('each', 'DET')
# ('wins', 'VERB')
# ('1x', 'PROPN')
# ('Hyena', 'PROPN')
# ('#', 'SYM')
# ('NFT', 'PROPN')
# ('chosen', 'VERB')
# ('TONIGHT', 'NOUN')
# ('@', 'ADP')
# ('10:00', 'NUM')
# ('PM', 'NOUN')
# ('EST', 'PROPN')
# ('⏰', 'NOUN')
# ('\n\n', 'SPACE')
# ('👇', 'VERB')
# ('To', 'PART')
# ('enter', 'VERB')
# (':', 'PUNCT')
# ('\n', 'SPACE')
# ('1⃣RT', 'PROPN')
# ('+', 'SYM')
# ('Follow', 'PROPN')
# ('@HedgeFundHyenas', 'PROPN')
# ('\n', 'SPACE')
# ('2⃣Join', 'NUM')
# ('Discord', 'PROPN')
# (':', 'PUNCT')
# ('https://t.co/Nk6ddqUjWw', 'NOUN')
# ('\n\n', 'SPACE')
# ('While', 'SCONJ')
# ('in', 'ADP')
# ('Discord', 'PROPN')
# (',', 'PUNCT')
# ('come', 'VERB')
# ('talk', 'VERB')
# ('NFT', 'PROPN')
# ('/', 'SYM')
# ('crypto', 'NOUN')
# ('investments', 'NOUN')
# ('with', 'ADP')
# ('our', 'PRON')
# ('#', 'SYM')
# ('NFTCommunity', 'NOUN')
# ('&', 'CCONJ')
# ('amp', 'NOUN')
# (';', 'PUNCT')
# ('the', 'DET')
# ('HFH', 'PROPN')
# ('team', 'NOUN')
# ('!', 'PUNCT')
# ('https://t.co/U8hdAX7qF7', 'X')
